# %% [markdown]
# # IT549 – Deep Learning | Lab 2
# ## GloVe Pretrained Embeddings for Movie Text Prediction
#
# **Name:** Dharmikkumar Mistry
# **Student ID:** 202511039

# %% [markdown]
# ## Imports & Setup

# %%
import os
import re
import json
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

import nltk
nltk.download('punkt', quiet=True)
nltk.download('punkt_tab', quiet=True)
nltk.download('wordnet', quiet=True)
nltk.download('stopwords', quiet=True)
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    mean_squared_error, f1_score, hamming_loss, jaccard_score
)

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset

warnings.filterwarnings('ignore')
SEED = 42
np.random.seed(SEED)
torch.manual_seed(SEED)

DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {DEVICE}")
print("All imports successful ✓")
# Out:
# Using device: cpu
# All imports successful ✓

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv('movies.csv')

# Keep only the allowed columns (with correct CSV names)
df = df[['genres', 'keywords', 'tagline', 'overview', 'vote_average']].copy()

# Rename to match assignment terminology
df.rename(columns={'genres': 'genre', 'vote_average': 'voting_average'}, inplace=True)

print(f"Dataset shape: {df.shape}")
print(f"\nNull counts:")
print(df.isnull().sum())
print(f"\nSample row:")
df.head()
# Out:
# Dataset shape: (4803, 5)
#
# Null counts:
# genre              28
# keywords          412
# tagline           844
# overview            3
# voting_average      0
# dtype: int64
#
# Sample row:
#                                       genre  \
# 0  Action Adventure Fantasy Science Fiction
# 1                  Adventure Fantasy Action
# 2                    Action Adventure Crime
# 3               Action Crime Drama Thriller
# 4          Action Adventure Science Fiction
#
#                                             keywords  \
# 0  culture clash future space war space colony so...
# 1  ocean drug abuse exotic island east india trad...
# 2         spy based on novel secret agent sequel mi6
# 3  dc comics crime fighter terrorist secret ident...
# 4  based on novel mars medallion space travel pri...
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                             overview  voting_average
# 0  In the 22nd century, a paraplegic Marine is di...             7.2
# 1  Captain Barbossa, long believed to be dead, ha...             6.9
# 2  A cryptic message from Bond’s past sends him o...             6.3
# 3  Following the death of District Attorney Harve...             7.6
# 4  John Carter is a war-weary, former military ca...             6.1

# %% [markdown]
# ## Data Cleaning & Missing Value Handling

# %%
# Drop rows where genre or voting_average is missing (critical targets)
df.dropna(subset=['genre', 'overview'], inplace=True)

# Fill missing text columns with empty string (avoids losing target rows)
for col in ['keywords', 'tagline']:
    df[col] = df[col].fillna('')

df.reset_index(drop=True, inplace=True)
print(f"Cleaned dataset shape: {df.shape}")
print(f"voting_average range: {df['voting_average'].min():.1f} – {df['voting_average'].max():.1f}")
print(f"voting_average mean: {df['voting_average'].mean():.3f}")
# Out:
# Cleaned dataset shape: (4772, 5)
# voting_average range: 0.0 – 10.0
# voting_average mean: 6.115

# %% [markdown]
# ## Parse Multi-Label Genres

# %%
# Split space-separated genre string into a list
# e.g., "Action Adventure Fantasy" → ['Action', 'Adventure', 'Fantasy']
df['genre_list'] = df['genre'].apply(lambda x: x.strip().split() if isinstance(x, str) else [])

# Count genre frequency
all_genres = [g for sublist in df['genre_list'] for g in sublist]
genre_counts = Counter(all_genres)
print(f"Total unique genres: {len(genre_counts)}")
print("\nTop 15 genres by frequency:")
for genre, count in genre_counts.most_common():
    print(f"  {genre:<25} {count}")
# Out:
# Total unique genres: 22
#
# Top 15 genres by frequency:
#   Drama                     2296
#   Comedy                    1722
#   Thriller                  1259
#   Action                    1153
#   Romance                   890
#   Adventure                 790
#   Crime                     696
#   Science                   530
#   Fiction                   530
#   Horror                    519
#   Family                    510
#   Fantasy                   418
#   Mystery                   347
#   Animation                 234
#   History                   197
#   Music                     183
#   War                       142
#   Documentary               108
#   Western                   80
#   Foreign                   34
#   TV                        8
#   Movie                     8

# %% [markdown]
# ## Text Preprocessing Function

# %%
lemmatizer = WordNetLemmatizer()
STOPWORDS = set(stopwords.words('english'))

def preprocess_text(text: str) -> list:
    if not isinstance(text, str) or text.strip() == '':
        return []
    text = text.lower()
    text = re.sub(r'http\S+|www\.\S+', '', text)
    text = re.sub(r'[^a-z\s]', '', text)
    tokens = word_tokenize(text)
    tokens = [
        lemmatizer.lemmatize(tok)
        for tok in tokens
        if tok not in STOPWORDS and len(tok) > 2
    ]
    return tokens

def tokens_to_string(tokens: list) -> str:
    return ' '.join(tokens)

# Apply preprocessing to all three text columns
print("Preprocessing text columns")
for col in ['overview', 'tagline', 'keywords']:
    df[f'{col}_tokens'] = df[col].apply(preprocess_text)
    df[f'{col}_clean'] = df[f'{col}_tokens'].apply(tokens_to_string)
    print(f"  ✓ {col} done")
print(df.shape)
# Preview
print("\nExample (overview):")
print(f"  ORIGINAL : {df['overview'].iloc[0][:80]}...")
print(f"  PROCESSED: {df['overview_clean'].iloc[0][:80]}...")

df.head()
# Out:
# Preprocessing text columns
#   ✓ overview done
#   ✓ tagline done
#   ✓ keywords done
# (4772, 12)
#
# Example (overview):
#   ORIGINAL : In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a ...
#   PROCESSED: century paraplegic marine dispatched moon pandora unique mission becomes torn fo...
#                                       genre  \
# 0  Action Adventure Fantasy Science Fiction
# 1                  Adventure Fantasy Action
# 2                    Action Adventure Crime
# 3               Action Crime Drama Thriller
# 4          Action Adventure Science Fiction
#
#                                             keywords  \
# 0  culture clash future space war space colony so...
# 1  ocean drug abuse exotic island east india trad...
# 2         spy based on novel secret agent sequel mi6
# 3  dc comics crime fighter terrorist secret ident...
# 4  based on novel mars medallion space travel pri...
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                             overview  voting_average  \
# 0  In the 22nd century, a paraplegic Marine is di...             7.2
# 1  Captain Barbossa, long believed to be dead, ha...             6.9
# 2  A cryptic message from Bond’s past sends him o...             6.3
# 3  Following the death of District Attorney Harve...             7.6
# 4  John Carter is a war-weary, former military ca...             6.1
#
#                                        genre_list  \
# 0  [Action, Adventure, Fantasy, Science, Fiction]
# 1                    [Adventure, Fantasy, Action]
# 2                      [Action, Adventure, Crime]
# 3                [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science, Fiction]
#
#                                      overview_tokens  \
# 0  [century, paraplegic, marine, dispatched, moon...
# 1  [captain, barbossa, long, believed, dead, come...
# 2  [cryptic, message, bond, past, sends, trail, u...
# 3  [following, death, district, attorney, harvey,...
# 4  [john, carter, warweary, former, military, cap...
#
#                                       overview_clean  \
# 0  century paraplegic marine dispatched moon pand...
# 1  captain barbossa long believed dead come back ...
# 2  cryptic message bond past sends trail uncover ...
# 3  following death district attorney harvey dent ...
# 4  john carter warweary former military captain w...
#
#                    tagline_tokens              tagline_clean  \
# 0         [enter, world, pandora]        enter world pandora
# 1  [end, world, adventure, begin]  end world adventure begin
# 2             [plan, one, escape]            plan one escape
# 3                   [legend, end]                 legend end
# 4   [lost, world, found, another]   lost world found another
#
#                                      keywords_tokens  \
# 0  [culture, clash, future, space, war, space, co...
# 1  [ocean, drug, abuse, exotic, island, east, ind...
# 2         [spy, based, novel, secret, agent, sequel]
# 3  [comic, crime, fighter, terrorist, secret, ide...
# 4  [based, novel, mar, medallion, space, travel, ...
#
#                                       keywords_clean
# 0  culture clash future space war space colony so...
# 1  ocean drug abuse exotic island east india trad...
# 2                spy based novel secret agent sequel
# 3  comic crime fighter terrorist secret identity ...
# 4    based novel mar medallion space travel princess

# %% [markdown]
# ## Train / Validation / Test Split (70 / 15 / 15)

# %%
# First split: 70% train, 30% temp
train_idx, temp_idx = train_test_split(
    df.index, test_size=0.30, random_state=SEED
)
# Second split: temp → 50% val (15%), 50% test (15%)
val_idx, test_idx = train_test_split(
    temp_idx, test_size=0.50, random_state=SEED
)

train_df = df.loc[train_idx].reset_index(drop=True)
val_df   = df.loc[val_idx].reset_index(drop=True)
test_df  = df.loc[test_idx].reset_index(drop=True)

print(f"Train size : {len(train_df)} ({len(train_df)/len(df)*100:.1f}%)")
print(f"Val size   : {len(val_df)} ({len(val_df)/len(df)*100:.1f}%)")
print(f"Test size  : {len(test_df)} ({len(test_df)/len(df)*100:.1f}%)")
# Out:
# Train size : 3340 (70.0%)
# Val size   : 716 (15.0%)
# Test size  : 716 (15.0%)

# %% [markdown]
# ## Load GloVe Vectors

# %%
GLOVE_PATH = 'glove.2024.wikigiga.100d/wiki_giga_2024_100_MFT20_vectors_seed_2024_alpha_0.75_eta_0.05.050_combined.txt'
GLOVE_DIM = 100                    # We use 100-dimensional GloVe

print(f"Loading GloVe {GLOVE_DIM}D vectors from: {GLOVE_PATH}")
glove = {}
with open(GLOVE_PATH, 'r', encoding='utf-8') as f:
    for line in f:
        parts = line.split()
        word = parts[0]
        try:
            vector = np.array(parts[1:], dtype=np.float32)
        except ValueError:
            continue  # skip malformed lines
        if len(vector) == GLOVE_DIM:
            glove[word] = vector

print(f"✓ Loaded {len(glove):,} GloVe word vectors (dim={GLOVE_DIM})")
# Out:
# Loading GloVe 100D vectors from: glove.2024.wikigiga.100d/wiki_giga_2024_100_MFT20_vectors_seed_2024_alpha_0.75_eta_0.05.050_combined.txt
# ✓ Loaded 1,287,614 GloVe word vectors (dim=100)

# %% [markdown]
# ## GloVe Coverage Report

# %%
def compute_coverage(token_series, glove_vocab):
    
    all_tokens = set(tok for tokens in token_series for tok in tokens)
    covered = {t for t in all_tokens if t in glove_vocab}
    pct = len(covered) / len(all_tokens) * 100 if all_tokens else 0
    return len(all_tokens), len(covered), pct

print("GloVe Embedding Coverage Report")
for col in ['overview', 'tagline', 'keywords']:
    total, covered, pct = compute_coverage(df[f'{col}_tokens'], glove)
    print(f"  {col:<12}: {covered:,} / {total:,} unique tokens  →  {pct:.1f}% covered")
# Out:
# GloVe Embedding Coverage Report
#   overview    : 18,495 / 20,248 unique tokens  →  91.3% covered
#   tagline     : 3,436 / 3,592 unique tokens  →  95.7% covered
#   keywords    : 4,056 / 4,172 unique tokens  →  97.2% covered

# %% [markdown]
# ## TF-IDF Weighted GloVe Document Embeddings

# %%
def build_tfidf_glove_embeddings(train_texts, all_texts, glove_vocab, dim=100):

    vectorizer = TfidfVectorizer(min_df=1)
    vectorizer.fit(train_texts)           
    vocab = vectorizer.vocabulary_        
    idf   = vectorizer.idf_               
    
    tfidf_matrix = vectorizer.transform(all_texts)
    
    embeddings = np.zeros((len(all_texts), dim), dtype=np.float32)
    
    for i in range(len(all_texts)):
        row = tfidf_matrix[i]                    # sparse row
        word_indices = row.indices               # columns with non-zero tfidf
        tfidf_weights = row.data                 # corresponding tfidf values
        
        weighted_sum = np.zeros(dim, dtype=np.float32)
        weight_total = 0.0
        
        index_to_word = {v: k for k, v in vocab.items()}
        
        for idx, weight in zip(word_indices, tfidf_weights):
            word = index_to_word.get(idx)
            if word and word in glove_vocab:
                weighted_sum += weight * glove_vocab[word]
                weight_total += weight
        
        if weight_total > 0:
            embeddings[i] = weighted_sum / weight_total
    
    return vectorizer, embeddings



embeddings = {}    
tfidf_vectorizers = {} 

for col in ['overview', 'tagline', 'keywords']:
    print(f"Building TF-IDF GloVe embeddings for: {col}")
    
    train_texts = train_df[f'{col}_clean'].tolist()
    val_texts   = val_df[f'{col}_clean'].tolist()
    test_texts  = test_df[f'{col}_clean'].tolist()
    all_texts   = train_texts + val_texts + test_texts
    
    vectorizer, all_emb = build_tfidf_glove_embeddings(
        train_texts, all_texts, glove, GLOVE_DIM
    )
    tfidf_vectorizers[col] = vectorizer
    
    n_train = len(train_texts)
    n_val   = len(val_texts)
    embeddings[col] = {
        'train': all_emb[:n_train],
        'val'  : all_emb[n_train:n_train+n_val],
        'test' : all_emb[n_train+n_val:]
    }
    print(f"Train: {embeddings[col]['train'].shape}, Val: {embeddings[col]['val'].shape}, Test: {embeddings[col]['test'].shape}")
# Out:
# Building TF-IDF GloVe embeddings for: overview
# Train: (3340, 100), Val: (716, 100), Test: (716, 100)
# Building TF-IDF GloVe embeddings for: tagline
# Train: (3340, 100), Val: (716, 100), Test: (716, 100)
# Building TF-IDF GloVe embeddings for: keywords
# Train: (3340, 100), Val: (716, 100), Test: (716, 100)

# %% [markdown]
# ## Neural Network Architecture
#
# We define two networks that share the same structure:
#
# | Layer | Regression | Classification |
# |-------|-----------|----------------|
# | Input | 100 (GloVe dim) | 100 |
# | Hidden 1 | 128, ReLU, Dropout 0.3 | 128, ReLU, Dropout 0.3 |
# | Hidden 2 | 64, ReLU | 64, ReLU |
# | Output | 1 (single float) | N_genres |

# %%
class RegressionNet(nn.Module):
    def __init__(self, input_dim=100):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 1)
        )
    def forward(self, x):
        return self.net(x).squeeze(-1)


class ClassificationNet(nn.Module):

    def __init__(self, input_dim=100, num_labels=20):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, num_labels)
        )
    def forward(self, x):
        return self.net(x)


print("Model architectures defined")
# Quick sanity check
dummy = torch.zeros(4, GLOVE_DIM)
reg_net = RegressionNet(GLOVE_DIM)
cls_net = ClassificationNet(GLOVE_DIM, num_labels=5)
print(f"  Regression output shape  : {reg_net(dummy).shape}  (expected: [4])")
print(f"  Classification output shape: {cls_net(dummy).shape}  (expected: [4, 5])")
# Out:
# Model architectures defined
#   Regression output shape  : torch.Size([4])  (expected: [4])
#   Classification output shape: torch.Size([4, 5])  (expected: [4, 5])

# %% [markdown]
# ## Training Helper Functions

# %%
def make_dataloader(X, y, batch_size=64, shuffle=True):
    X_t = torch.tensor(X, dtype=torch.float32)
    y_t = torch.tensor(y, dtype=torch.float32)
    return DataLoader(TensorDataset(X_t, y_t), batch_size=batch_size, shuffle=shuffle)


def train_model(model, train_loader, val_loader, loss_fn, 
                epochs=50, lr=1e-3, task='regression'):
                
    model.to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=1e-4)
    
    history = {'train_loss': [], 'val_loss': []}
    
    for epoch in range(epochs):
        # --- Training ---
        model.train()
        total_loss = 0
        for Xb, yb in train_loader:
            Xb, yb = Xb.to(DEVICE), yb.to(DEVICE)
            optimizer.zero_grad()
            preds = model(Xb)
            loss = loss_fn(preds, yb)
            loss.backward()
            optimizer.step()
            total_loss += loss.item() * len(Xb)
        
        # --- Validation ---
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for Xb, yb in val_loader:
                Xb, yb = Xb.to(DEVICE), yb.to(DEVICE)
                preds = model(Xb)
                val_loss += loss_fn(preds, yb).item() * len(Xb)
        
        history['train_loss'].append(total_loss / len(train_loader.dataset))
        history['val_loss'].append(val_loss / len(val_loader.dataset))
        
        if (epoch + 1) % 10 == 0:
            print(f"  Epoch {epoch+1:3d}/{epochs} | "
                  f"Train Loss: {history['train_loss'][-1]:.4f} | "
                  f"Val Loss: {history['val_loss'][-1]:.4f}")
    
    return history


def plot_loss_curve(history, title='Training Curve'):
    plt.figure(figsize=(8, 4))
    plt.plot(history['train_loss'], label='Train Loss')
    plt.plot(history['val_loss'],   label='Val Loss')
    plt.xlabel('Epoch'); plt.ylabel('Loss')
    plt.title(title); plt.legend(); plt.tight_layout()
    plt.show()

print("Training helpers defined")
# Out:
# Training helpers defined

# %% [markdown]
# ## Prepare Regression Targets

# %%
y_reg_train = train_df['voting_average'].values.astype(np.float32)
y_reg_val   = val_df['voting_average'].values.astype(np.float32)
y_reg_test  = test_df['voting_average'].values.astype(np.float32)

GLOBAL_MEAN = y_reg_train.mean()
print(f"Global mean rating (baseline prediction): {GLOBAL_MEAN:.4f}")

# Baseline model: always predict the global mean
baseline_preds = np.full_like(y_reg_test, GLOBAL_MEAN)
baseline_mse  = mean_squared_error(y_reg_test, baseline_preds)
baseline_rmse = np.sqrt(baseline_mse)
print(f"Baseline MSE  (predict mean always): {baseline_mse:.4f}")
print(f"Baseline RMSE (predict mean always): {baseline_rmse:.4f}")
# Out:
# Global mean rating (baseline prediction): 6.1184
# Baseline MSE  (predict mean always): 1.2557
# Baseline RMSE (predict mean always): 1.1206

# %% [markdown]
# ## Task 3A: Regression with `overview` Embeddings

# %%
col = 'overview'
print(f"Regression: input = '{col}'")

X_tr = embeddings[col]['train']
X_va = embeddings[col]['val']
X_te = embeddings[col]['test']

train_loader_reg = make_dataloader(X_tr, y_reg_train)
val_loader_reg   = make_dataloader(X_va, y_reg_val, shuffle=False)

reg_model_overview = RegressionNet(GLOVE_DIM).to(DEVICE)
loss_fn_reg = nn.MSELoss()

history_reg_overview = train_model(
    reg_model_overview, train_loader_reg, val_loader_reg,
    loss_fn_reg, epochs=80, lr=1e-3
)

# Evaluate on test set
reg_model_overview.eval()
with torch.no_grad():
    preds_overview = reg_model_overview(
        torch.tensor(X_te, dtype=torch.float32).to(DEVICE)
    ).cpu().numpy()

mse_overview  = mean_squared_error(y_reg_test, preds_overview)
rmse_overview = np.sqrt(mse_overview)
print(f"\nTEST RESULTS (overview)")
print(f"  MSE  : {mse_overview:.4f}")
print(f"  RMSE : {rmse_overview:.4f}")
print(f"  Baseline RMSE: {baseline_rmse:.4f}  ({'↓ improved' if rmse_overview < baseline_rmse else '↑ NOT better than baseline'})")

plot_loss_curve(history_reg_overview, f'Regression Training Curve {col}')
# Out:
# Regression: input = 'overview'
#   Epoch  10/80 | Train Loss: 1.5136 | Val Loss: 1.3794
#   Epoch  20/80 | Train Loss: 1.3206 | Val Loss: 1.3377
#   Epoch  30/80 | Train Loss: 1.2097 | Val Loss: 1.3510
#   Epoch  40/80 | Train Loss: 1.1756 | Val Loss: 1.3879
#   Epoch  50/80 | Train Loss: 1.1038 | Val Loss: 1.3652
#   Epoch  60/80 | Train Loss: 1.0713 | Val Loss: 1.4282
#   Epoch  70/80 | Train Loss: 0.9939 | Val Loss: 1.3983
#   Epoch  80/80 | Train Loss: 0.9369 | Val Loss: 1.4423
#
# TEST RESULTS (overview)
#   MSE  : 1.3067
#   RMSE : 1.1431
#   Baseline RMSE: 1.1206  (↑ NOT better than baseline)

# %% [markdown]
# ## Task 3B: Regression with `keywords` Embeddings

# %%
col = 'keywords'
print(f"Regression: input = '{col}'")

X_tr = embeddings[col]['train']
X_va = embeddings[col]['val']
X_te = embeddings[col]['test']

train_loader_reg_kw = make_dataloader(X_tr, y_reg_train)
val_loader_reg_kw   = make_dataloader(X_va, y_reg_val, shuffle=False)

reg_model_keywords = RegressionNet(GLOVE_DIM).to(DEVICE)

history_reg_keywords = train_model(
    reg_model_keywords, train_loader_reg_kw, val_loader_reg_kw,
    loss_fn_reg, epochs=80, lr=1e-3
)

reg_model_keywords.eval()
with torch.no_grad():
    preds_keywords = reg_model_keywords(
        torch.tensor(X_te, dtype=torch.float32).to(DEVICE)
    ).cpu().numpy()

mse_keywords  = mean_squared_error(y_reg_test, preds_keywords)
rmse_keywords = np.sqrt(mse_keywords)
print(f"\nTEST RESULTS (keywords)")
print(f"  MSE  : {mse_keywords:.4f}")
print(f"  RMSE : {rmse_keywords:.4f}")
print(f"  Baseline RMSE: {baseline_rmse:.4f}")

plot_loss_curve(history_reg_keywords, f'Regression Training Curve – {col}')
# Out:
# Regression: input = 'keywords'
#   Epoch  10/80 | Train Loss: 1.3553 | Val Loss: 1.3811
#   Epoch  20/80 | Train Loss: 1.2928 | Val Loss: 1.4036
#   Epoch  30/80 | Train Loss: 1.2095 | Val Loss: 1.3560
#   Epoch  40/80 | Train Loss: 1.1859 | Val Loss: 1.4407
#   Epoch  50/80 | Train Loss: 1.1146 | Val Loss: 1.4467
#   Epoch  60/80 | Train Loss: 1.0722 | Val Loss: 1.3993
#   Epoch  70/80 | Train Loss: 1.0247 | Val Loss: 1.3899
#   Epoch  80/80 | Train Loss: 1.0279 | Val Loss: 1.4873
#
# TEST RESULTS (keywords)
#   MSE  : 1.2386
#   RMSE : 1.1129
#   Baseline RMSE: 1.1206

# %% [markdown]
# ## Task 3C: Regression with `tagline` Embeddings

# %%
col = 'tagline'
print(f"Regression: input = '{col}'")

X_tr = embeddings[col]['train']
X_va = embeddings[col]['val']
X_te = embeddings[col]['test']

train_loader_reg_tg = make_dataloader(X_tr, y_reg_train)
val_loader_reg_tg   = make_dataloader(X_va, y_reg_val, shuffle=False)

reg_model_tagline = RegressionNet(GLOVE_DIM).to(DEVICE)

history_reg_tagline = train_model(
    reg_model_tagline, train_loader_reg_tg, val_loader_reg_tg,
    loss_fn_reg, epochs=80, lr=1e-3
)

reg_model_tagline.eval()
with torch.no_grad():
    preds_tagline = reg_model_tagline(
        torch.tensor(X_te, dtype=torch.float32).to(DEVICE)
    ).cpu().numpy()

mse_tagline  = mean_squared_error(y_reg_test, preds_tagline)
rmse_tagline = np.sqrt(mse_tagline)
print(f"\nTEST RESULTS (tagline)")
print(f"  MSE  : {mse_tagline:.4f}")
print(f"  RMSE : {rmse_tagline:.4f}")
print(f"  Baseline RMSE: {baseline_rmse:.4f}")

plot_loss_curve(history_reg_tagline, f'Regression Training Curve – {col}')
# Out:
# Regression: input = 'tagline'
#   Epoch  10/80 | Train Loss: 1.4481 | Val Loss: 1.3955
#   Epoch  20/80 | Train Loss: 1.3259 | Val Loss: 1.4583
#   Epoch  30/80 | Train Loss: 1.1883 | Val Loss: 1.4531
#   Epoch  40/80 | Train Loss: 1.1833 | Val Loss: 1.3861
#   Epoch  50/80 | Train Loss: 1.1134 | Val Loss: 1.4845
#   Epoch  60/80 | Train Loss: 1.0404 | Val Loss: 1.4099
#   Epoch  70/80 | Train Loss: 1.0178 | Val Loss: 1.4626
#   Epoch  80/80 | Train Loss: 0.9903 | Val Loss: 1.4801
#
# TEST RESULTS (tagline)
#   MSE  : 1.4978
#   RMSE : 1.2239
#   Baseline RMSE: 1.1206

# %% [markdown]
# ## Regression Results Comparison Table

# %%
reg_results = pd.DataFrame({
    'Model / Input': ['Baseline (mean)', 'Neural Net - overview', 'Neural Net - keywords', 'Neural Net - Tagline'],
    'MSE': [round(baseline_mse, 4), round(mse_overview, 4), round(mse_keywords, 4), round(mse_tagline, 4)],
    'RMSE': [round(baseline_rmse, 4), round(rmse_overview, 4), round(rmse_keywords, 4), round(rmse_tagline, 4)]
})
print("Task 3: Regression Results")
print(reg_results.to_string(index=False))

# Bar chart
plt.figure(figsize=(8, 4))
plt.bar(reg_results['Model / Input'], reg_results['RMSE'], color=['gray', 'steelblue', 'darkorange'])
plt.ylabel('RMSE')
plt.title('Task 3: Regression RMSE Comparison')
plt.xticks(rotation=15, ha='right')
plt.tight_layout()
plt.show()
# Out:
# Task 3: Regression Results
#         Model / Input    MSE   RMSE
#       Baseline (mean) 1.2557 1.1206
# Neural Net - overview 1.3067 1.1431
# Neural Net - keywords 1.2386 1.1129
#  Neural Net - Tagline 1.4978 1.2239

# %% [markdown]
# ## Prepare Multi-Label Classification Targets

# %%
MIN_GENRE_FREQ = 50
valid_genres = {g for g, c in genre_counts.items() if c >= MIN_GENRE_FREQ}
print(f"Genres with >={MIN_GENRE_FREQ} occurrences: {sorted(valid_genres)}")
print(f"Total: {len(valid_genres)} genres")

# Filter genre lists to only include valid genres
def filter_genres(genre_list):
    return [g for g in genre_list if g in valid_genres]

df['genre_filtered'] = df['genre_list'].apply(filter_genres)
train_df['genre_filtered'] = train_df['genre_list'].apply(filter_genres)
val_df['genre_filtered']   = val_df['genre_list'].apply(filter_genres)
test_df['genre_filtered']  = test_df['genre_list'].apply(filter_genres)

mlb = MultiLabelBinarizer(classes=sorted(valid_genres))
mlb.fit(train_df['genre_filtered'])

y_cls_train = mlb.transform(train_df['genre_filtered']).astype(np.float32)
y_cls_val   = mlb.transform(val_df['genre_filtered']).astype(np.float32)
y_cls_test  = mlb.transform(test_df['genre_filtered']).astype(np.float32)

NUM_LABELS = len(mlb.classes_)
print(f"\nLabel matrix shapes → train: {y_cls_train.shape}, val: {y_cls_val.shape}, test: {y_cls_test.shape}")
print(f"Genre labels: {list(mlb.classes_)}")
# Out:
# Genres with >=50 occurrences: ['Action', 'Adventure', 'Animation', 'Comedy', 'Crime', 'Documentary', 'Drama', 'Family', 'Fantasy', 'Fiction', 'History', 'Horror', 'Music', 'Mystery', 'Romance', 'Science', 'Thriller', 'War', 'Western']
# Total: 19 genres
#
# Label matrix shapes → train: (3340, 19), val: (716, 19), test: (716, 19)
# Genre labels: ['Action', 'Adventure', 'Animation', 'Comedy', 'Crime', 'Documentary', 'Drama', 'Family', 'Fantasy', 'Fiction', 'History', 'Horror', 'Music', 'Mystery', 'Romance', 'Science', 'Thriller', 'War', 'Western']

# %% [markdown]
# ## Task 4A: Multi-Label Genre Classification with `overview`

# %%
col = 'overview'
print(f"Multi-Label Classification: input = '{col}'")

X_tr = embeddings[col]['train']
X_va = embeddings[col]['val']
X_te = embeddings[col]['test']

train_loader_cls = make_dataloader(X_tr, y_cls_train)
val_loader_cls   = make_dataloader(X_va, y_cls_val, shuffle=False)

cls_model_overview = ClassificationNet(GLOVE_DIM, NUM_LABELS).to(DEVICE)
loss_fn_cls = nn.BCEWithLogitsLoss()

history_cls_overview = train_model(
    cls_model_overview, train_loader_cls, val_loader_cls,
    loss_fn_cls, epochs=80, lr=1e-3, task='classification'
)

# Predict on test set
cls_model_overview.eval()
with torch.no_grad():
    logits_overview = cls_model_overview(
        torch.tensor(X_te, dtype=torch.float32).to(DEVICE)
    ).cpu().numpy()

probs_overview = 1 / (1 + np.exp(-logits_overview))
preds_cls_overview = (probs_overview >= 0.5).astype(int)

micro_f1_ov = f1_score(y_cls_test, preds_cls_overview, average='micro', zero_division=0)
macro_f1_ov = f1_score(y_cls_test, preds_cls_overview, average='macro', zero_division=0)
ham_ov      = hamming_loss(y_cls_test, preds_cls_overview)
jac_ov      = jaccard_score(y_cls_test, preds_cls_overview, average='samples', zero_division=0)

print(f"\nTEST RESULTS (overview)")
print(f"  Micro-F1     : {micro_f1_ov:.4f}")
print(f"  Macro-F1     : {macro_f1_ov:.4f}")
print(f"  Hamming Loss : {ham_ov:.4f}")
print(f"  Jaccard Score: {jac_ov:.4f}")

plot_loss_curve(history_cls_overview, f'Classification Training Curve – {col}')
# Out:
# Multi-Label Classification: input = 'overview'
#   Epoch  10/80 | Train Loss: 0.2735 | Val Loss: 0.2796
#   Epoch  20/80 | Train Loss: 0.2553 | Val Loss: 0.2655
#   Epoch  30/80 | Train Loss: 0.2472 | Val Loss: 0.2637
#   Epoch  40/80 | Train Loss: 0.2419 | Val Loss: 0.2600
#   Epoch  50/80 | Train Loss: 0.2375 | Val Loss: 0.2592
#   Epoch  60/80 | Train Loss: 0.2330 | Val Loss: 0.2597
#   Epoch  70/80 | Train Loss: 0.2283 | Val Loss: 0.2596
#   Epoch  80/80 | Train Loss: 0.2269 | Val Loss: 0.2592
#
# TEST RESULTS (overview)
#   Micro-F1     : 0.5564
#   Macro-F1     : 0.4197
#   Hamming Loss : 0.1049
#   Jaccard Score: 0.4362

# %% [markdown]
# ## Task 4B: Multi-Label Classification with `keywords`

# %%
col = 'keywords'
print(f"Multi-Label Classification: input = '{col}'")

X_tr = embeddings[col]['train']
X_va = embeddings[col]['val']
X_te = embeddings[col]['test']

train_loader_cls_kw = make_dataloader(X_tr, y_cls_train)
val_loader_cls_kw   = make_dataloader(X_va, y_cls_val, shuffle=False)

cls_model_keywords = ClassificationNet(GLOVE_DIM, NUM_LABELS).to(DEVICE)

history_cls_keywords = train_model(
    cls_model_keywords, train_loader_cls_kw, val_loader_cls_kw,
    loss_fn_cls, epochs=80, lr=1e-3
)

cls_model_keywords.eval()
with torch.no_grad():
    logits_kw = cls_model_keywords(
        torch.tensor(X_te, dtype=torch.float32).to(DEVICE)
    ).cpu().numpy()

probs_kw = 1 / (1 + np.exp(-logits_kw))
preds_cls_keywords = (probs_kw >= 0.5).astype(int)

micro_f1_kw = f1_score(y_cls_test, preds_cls_keywords, average='micro', zero_division=0)
macro_f1_kw = f1_score(y_cls_test, preds_cls_keywords, average='macro', zero_division=0)
ham_kw      = hamming_loss(y_cls_test, preds_cls_keywords)
jac_kw      = jaccard_score(y_cls_test, preds_cls_keywords, average='samples', zero_division=0)

print(f"\nTEST RESULTS (keywords)")
print(f"  Micro-F1     : {micro_f1_kw:.4f}")
print(f"  Macro-F1     : {macro_f1_kw:.4f}")
print(f"  Hamming Loss : {ham_kw:.4f}")
print(f"  Jaccard Score: {jac_kw:.4f}")

plot_loss_curve(history_cls_keywords, f'Classification Training Curve – {col}')
# Out:
# Multi-Label Classification: input = 'keywords'
#   Epoch  10/80 | Train Loss: 0.2771 | Val Loss: 0.2878
#   Epoch  20/80 | Train Loss: 0.2642 | Val Loss: 0.2848
#   Epoch  30/80 | Train Loss: 0.2564 | Val Loss: 0.2847
#   Epoch  40/80 | Train Loss: 0.2505 | Val Loss: 0.2863
#   Epoch  50/80 | Train Loss: 0.2446 | Val Loss: 0.2866
#   Epoch  60/80 | Train Loss: 0.2374 | Val Loss: 0.2888
#   Epoch  70/80 | Train Loss: 0.2321 | Val Loss: 0.2914
#   Epoch  80/80 | Train Loss: 0.2276 | Val Loss: 0.2919
#
# TEST RESULTS (keywords)
#   Micro-F1     : 0.5055
#   Macro-F1     : 0.3931
#   Hamming Loss : 0.1129
#   Jaccard Score: 0.3748

# %% [markdown]
# ## Classification Results Comparison Table

# %%
cls_results = pd.DataFrame({
    'Input Column': ['overview', 'keywords'],
    'Micro-F1':     [round(micro_f1_ov, 4), round(micro_f1_kw, 4)],
    'Macro-F1':     [round(macro_f1_ov, 4), round(macro_f1_kw, 4)],
    'Hamming Loss': [round(ham_ov, 4), round(ham_kw, 4)],
    'Jaccard':      [round(jac_ov, 4), round(jac_kw, 4)]
})
print("Task 4: Multi-Label Classification Results")
print(cls_results.to_string(index=False))

# Grouped bar chart
fig, ax = plt.subplots(figsize=(9, 4))
x = np.arange(2)
width = 0.2
ax.bar(x - 1.5*width, cls_results['Micro-F1'],  width, label='Micro-F1')
ax.bar(x - 0.5*width, cls_results['Macro-F1'],  width, label='Macro-F1')
ax.bar(x + 0.5*width, cls_results['Jaccard'],   width, label='Jaccard')
ax.bar(x + 1.5*width, cls_results['Hamming Loss'], width, label='Hamming Loss')
ax.set_xticks(x); ax.set_xticklabels(['overview', 'keywords'])
ax.set_title('Task 4: Classification Metrics Comparison')
ax.legend(); plt.tight_layout(); plt.show()
# Out:
# Task 4: Multi-Label Classification Results
# Input Column  Micro-F1  Macro-F1  Hamming Loss  Jaccard
#     overview    0.5564    0.4197        0.1049   0.4362
#     keywords    0.5055    0.3931        0.1129   0.3748

# %% [markdown]
# ## Task 5: Top 10 Most Frequent Words per Genre

# %%
def genre_word_freq(genre_name, full_df, text_col='overview_tokens', min_freq=3):
    genre_mask = full_df['genre_list'].apply(lambda lst: genre_name in lst)
    tokens = [tok for tlist in full_df.loc[genre_mask, text_col] for tok in tlist]
    freq = Counter(tokens)
    freq_filtered = {w: c for w, c in freq.items() if c >= min_freq}
    return Counter(freq_filtered)


MIN_FREQ = 3
GENRES_TO_ANALYZE = sorted(valid_genres)

freq_results = {}
for genre in GENRES_TO_ANALYZE:
    freq_results[genre] = genre_word_freq(genre, df, min_freq=MIN_FREQ)

print(f"{'Genre':<20} {'TOP 10 MOST FREQUENT':^60} {'BOTTOM 10 LEAST FREQ':^60}")
print("-" * 140)

for genre in GENRES_TO_ANALYZE:
    counter = freq_results[genre]
    if len(counter) == 0:
        continue
    top10 = ', '.join([f"{w}({c})" for w, c in counter.most_common(10)])
    bot10 = ', '.join([f"{w}({c})" for w, c in counter.most_common()[:-11:-1]])
    print(f"{genre:<20} {top10:<60} {bot10:<60}")
# Out:
# Genre                                    TOP 10 MOST FREQUENT                                         BOTTOM 10 LEAST FREQ
# --------------------------------------------------------------------------------------------------------------------------------------------
# Action               world(187), find(187), life(168), one(166), must(165), new(160), man(134), two(130), take(126), get(119) guitar(3), wiley(3), reagan(3), fred(3), evening(3), entei(3), stegman(3), hazen(3), gasoline(3), stagecoach(3)
# Adventure            world(175), find(172), life(124), new(124), must(122), one(107), young(105), two(95), take(86), friend(82) wiley(3), ness(3), loch(3), herzog(3), goon(3), mcmaster(3), entei(3), taylor(3), hazen(3), deke(3)
# Animation            world(69), find(59), new(52), life(50), friend(43), one(40), get(39), adventure(39), must(39), young(36) entei(3), parrotmon(3), digimon(3), kaneda(3), brendan(3), episode(3), recess(3), kai(3), anything(3), humphrey(3)
# Comedy               life(381), find(301), new(286), friend(280), get(269), one(266), two(222), love(213), family(191), man(187) elie(3), horace(3), carlisle(3), wiley(3), ness(3), loch(3), herzog(3), kirby(3), initiate(3), addict(3)
# Crime                life(122), one(115), find(108), new(98), police(93), get(87), two(86), family(85), take(79), man(77) guitar(3), dominican(3), palestinian(3), clayton(3), polly(3), telly(3), caul(3), ashley(3), tracy(3), scout(3)
# Documentary          film(44), documentary(33), world(27), life(27), year(23), american(19), new(19), story(18), one(18), look(17) creator(3), emotional(3), hunt(3), cat(3), call(3), case(3), parent(3), recording(3), group(3), wrestling(3)
# Drama                life(690), find(361), story(355), young(339), family(334), new(330), one(322), man(299), love(294), world(275) maxwell(3), larisa(3), hoyle(3), dominican(3), carlisle(3), abortion(3), cooly(3), clayton(3), dodge(3), pakistani(3)
# Family               world(119), find(114), life(112), friend(102), new(92), get(87), young(86), family(82), must(74), one(71) nellie(3), church(3), carlisle(3), dancing(3), kathy(3), entei(3), austin(3), parrotmon(3), digimon(3), coast(3)
# Fantasy              world(103), find(86), life(84), young(67), must(67), evil(64), new(63), one(51), love(48), man(48) elvis(3), touch(3), entei(3), hazen(3), ash(3), parrotmon(3), digimon(3), dar(3), richard(3), redferne(3)
# Fiction              world(128), find(108), earth(99), life(90), one(84), year(82), must(82), planet(80), alien(79), new(76) compton(3), cortner(3), hoyle(3), melvin(3), carlisle(3), sophie(3), journalist(3), art(3), frank(3), mask(3)
# History              war(61), story(54), life(40), world(39), army(29), film(28), american(23), find(22), one(22), british(22) recording(3), sophie(3), tom(3), rafael(3), helen(3), katadreuffe(3), keep(3), algeria(3), adonijah(3), august(3)
# Horror               life(83), new(83), one(81), find(78), young(74), year(72), group(70), friend(67), family(64), begin(56) callie(3), compton(3), cortner(3), asylum(3), elvis(3), sandy(3), ness(3), loch(3), herzog(3), figure(3)
# Music                life(55), new(36), one(35), music(30), world(28), band(28), story(28), musical(26), singer(24), dream(22) eddie(3), harriet(3), mali(3), horace(3), scorsese(3), roger(3), stumble(3), visit(3), hilarious(3), brought(3)
# Mystery              find(80), life(73), one(58), man(47), new(45), young(43), year(42), world(40), murder(39), two(36) callie(3), hoyle(3), near(3), clayton(3), elvis(3), edwardes(3), caul(3), grove(3), downer(3), rosow(3)
# Romance              life(284), love(268), find(165), woman(161), young(154), new(136), one(132), man(131), friend(130), two(126) elie(3), horace(3), ricky(3), ruby(3), reason(3), selling(3), glenn(3), aviv(3), tel(3), tony(3)
# Science              world(128), find(108), earth(99), life(90), one(84), year(82), must(82), planet(80), alien(79), new(76) compton(3), cortner(3), hoyle(3), melvin(3), carlisle(3), sophie(3), journalist(3), art(3), frank(3), mask(3)
# Thriller             life(238), find(226), one(183), new(176), man(162), young(156), world(140), must(130), take(130), family(129) guitar(3), callie(3), hoyle(3), clayton(3), reagan(3), edwardes(3), downer(3), rosow(3), fred(3), duncan(3)
# War                  war(85), world(45), army(37), find(26), american(24), soldier(24), life(22), story(21), mission(20), young(20) rafael(3), memory(3), adonijah(3), train(3), middle(3), irish(3), dog(3), adam(3), barry(3), classic(3)
# Western              town(24), west(17), outlaw(16), gang(15), find(15), young(15), take(13), war(12), sheriff(12), friend(12) everyone(3), stagecoach(3), hogue(3), desert(3), cavalry(3), death(3), stranger(3), sean(3), guide(3), regiment(3)

# %% [markdown]
# ## Task 5: Visualize Top 10 Words for Selected Genres

# %%
# Plot top-10 word frequency bar charts for a selection of genres
PLOT_GENRES = sorted(valid_genres)[:6]

fig, axes = plt.subplots(2, 3, figsize=(15, 8))
axes = axes.flatten()

for ax, genre in zip(axes, PLOT_GENRES):
    counter = freq_results[genre]
    if not counter:
        ax.set_visible(False)
        continue
    words, counts = zip(*counter.most_common(10))
    ax.barh(list(words)[::-1], list(counts)[::-1], color='steelblue')
    ax.set_title(f"Top 10 Words – {genre}", fontsize=11)
    ax.set_xlabel('Frequency')

plt.suptitle('Task 5: Most Frequent Words per Genre (overview)', fontsize=13, y=1.01)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Task 6: Genre-Indicative Words via TF-IDF + Logistic Regression

# %%
# Fit TF-IDF on training set overview texts
tfidf_for_logreg = TfidfVectorizer(max_features=5000, min_df=3)
tfidf_for_logreg.fit(train_df['overview_clean'])

X_full_tfidf = tfidf_for_logreg.transform(df['overview_clean'])
feature_names = np.array(tfidf_for_logreg.get_feature_names_out())

# Use full dataset for indicative word extraction
X_train_tfidf = tfidf_for_logreg.transform(train_df['overview_clean'])

print("Training one logistic regression per genre")
indicative_words = {}

for i, genre in enumerate(sorted(valid_genres)):
    # Binary label: 1 if movie is in this genre, 0 otherwise
    y_binary = (y_cls_train[:, i] == 1).astype(int)
    
    if y_binary.sum() < 10:   # skip genres with too few positive examples in train
        continue
    
    clf = LogisticRegression(max_iter=1000, C=1.0, solver='lbfgs')
    clf.fit(X_train_tfidf, y_binary)
    
    # Get top 10 positive-weight feature indices
    coefs = clf.coef_[0]
    top10_idx = coefs.argsort()[-10:][::-1]
    indicative_words[genre] = list(feature_names[top10_idx])
    
print("Done")
# Out:
# Training one logistic regression per genre
# Done

# %% [markdown]
# ## Task 6: Display Indicative Words Table

# %%
print(f"{'GENRE':<20} {'TOP 10 INDICATIVE WORDS (TF-IDF + Logistic Regression)'}")

for genre, words in sorted(indicative_words.items()):
    print(f"{genre:<20} {', '.join(words)}")

indic_df = pd.DataFrame([
    {'Genre': genre, 'Indicative Words': ', '.join(words)}
    for genre, words in sorted(indicative_words.items())
])
indic_df
# Out:
# GENRE                TOP 10 INDICATIVE WORDS (TF-IDF + Logistic Regression)
# Action               agent, cop, criminal, fight, ruthless, hero, terrorist, assassin, target, james
# Adventure            adventure, bond, save, power, king, jungle, world, earth, dragon, force
# Animation            adventure, human, world, animated, save, dragon, city, animal, monster, journey
# Comedy               comedy, friend, big, show, girlfriend, guy, wedding, doesnt, think, single
# Crime                police, drug, cop, criminal, fbi, murder, crime, money, city, killer
# Documentary          documentary, look, film, filmmaker, footage, interview, michael, state, music, global
# Drama                story, life, struggle, love, wife, drama, family, mother, boy, based
# Family               adventure, dog, save, boy, christmas, little, land, world, friend, animal
# Fantasy              evil, vampire, dragon, ancient, power, king, world, century, magic, battle
# Fiction              alien, planet, earth, future, space, power, scientist, human, robot, time
# History              war, story, british, army, queen, chronicle, slave, irish, nation, retelling
# Horror               vampire, horror, zombie, creature, deadly, nightmare, group, terrifying, evil, killer
# Music                musical, singer, music, band, show, musician, competition, dream, dancer, rock
# Mystery              murder, clue, mysterious, killer, investigation, memory, past, death, fbi, mystery
# Romance              love, woman, romance, fall, meet, romantic, lover, relationship, girl, win
# Science              alien, planet, earth, future, space, power, scientist, human, robot, time
# Thriller             murder, killer, agent, police, thriller, secret, bond, terrorist, murdered, assassin
# War                  war, army, soldier, persian, world, general, battle, camp, american, german
# Western              west, outlaw, gang, town, civil, cattle, sheriff, lawman, gold, texas
#           Genre                                   Indicative Words
# 0        Action  agent, cop, criminal, fight, ruthless, hero, t...
# 1     Adventure  adventure, bond, save, power, king, jungle, wo...
# 2     Animation  adventure, human, world, animated, save, drago...
# 3        Comedy  comedy, friend, big, show, girlfriend, guy, we...
# 4         Crime  police, drug, cop, criminal, fbi, murder, crim...
# 5   Documentary  documentary, look, film, filmmaker, footage, i...
# 6         Drama  story, life, struggle, love, wife, drama, fami...
# 7        Family  adventure, dog, save, boy, christmas, little, ...
# 8       Fantasy  evil, vampire, dragon, ancient, power, king, w...
# 9       Fiction  alien, planet, earth, future, space, power, sc...
# 10      History  war, story, british, army, queen, chronicle, s...
# 11       Horror  vampire, horror, zombie, creature, deadly, nig...
# 12        Music  musical, singer, music, band, show, musician, ...
# 13      Mystery  murder, clue, mysterious, killer, investigatio...
# 14      Romance  love, woman, romance, fall, meet, romantic, lo...
# 15      Science  alien, planet, earth, future, space, power, sc...
# 16     Thriller  murder, killer, agent, police, thriller, secre...
# 17          War  war, army, soldier, persian, world, general, b...
# 18      Western  west, outlaw, gang, town, civil, cattle, sheri...

# %% [markdown]
# ## Final Results Summary

# %%
print("FINAL RESULTS SUMMARY: IT549 Lab 2\n")
print("GloVe Embedding: 100D (wiki_giga_2024, ~1.29M words)")
print("Embedding Method: TF-IDF Weighted Average")
print("Split: 70% train / 15% val / 15% test")
print()

print("TASK 3: Regression")
print(f"  Baseline RMSE : {baseline_rmse:.4f}")
print(f"  Neural Net [overview]    RMSE  : {rmse_overview:.4f}")
print(f"  Neural Net [keywords]    RMSE  : {rmse_keywords:.4f}")
print(f"  Neural Net [tagline]     RMSE  : {rmse_tagline:.4f}")
print()

print("TASK 4: Multi-Label Classification (predict genres)")
print(f"  Neural Net [overview]  Micro-F1: {micro_f1_ov:.4f}  Macro-F1: {macro_f1_ov:.4f}  Hamming: {ham_ov:.4f}")
print(f"  Neural Net [keywords]  Micro-F1: {micro_f1_kw:.4f}  Macro-F1: {macro_f1_kw:.4f}  Hamming: {ham_kw:.4f}")
print()
# Out:
# FINAL RESULTS SUMMARY: IT549 Lab 2
#
# GloVe Embedding: 100D (wiki_giga_2024, ~1.29M words)
# Embedding Method: TF-IDF Weighted Average
# Split: 70% train / 15% val / 15% test
#
# TASK 3: Regression
#   Baseline RMSE : 1.1206
#   Neural Net [overview]    RMSE  : 1.1431
#   Neural Net [keywords]    RMSE  : 1.1129
#   Neural Net [tagline]     RMSE  : 1.2239
#
# TASK 4: Multi-Label Classification (predict genres)
#   Neural Net [overview]  Micro-F1: 0.5564  Macro-F1: 0.4197  Hamming: 0.1049
#   Neural Net [keywords]  Micro-F1: 0.5055  Macro-F1: 0.3931  Hamming: 0.1129
